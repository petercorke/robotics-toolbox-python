# %% [markdown]
# <table>
#   <tr>
#     <td><div align="left"><font size="30">Robotics Toolbox for Python</font></div></td>
#     <td><img src="figs/RobToolBox_RoundLogoB.png" width="300"></td>
#   </tr>
# </table>
#
# <p></p>
# <div align="center" style="font-size: 1.5em;">Try the Robotics Toolbox for Python in your browser</div>
# <p></p>
#
# This is a JupyterLite deployment -- everything runs in your browser via Pyodide, no installation required.
#
# Notebooks:
#
# - [Robotics Toolbox tour](robotics.ipynb)
