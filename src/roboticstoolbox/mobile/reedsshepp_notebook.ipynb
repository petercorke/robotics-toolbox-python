# %%
from roboticstoolbox.mobile.reedsshepp import ReedsShepp
import math
import numpy as np

max_curve = 1 / 5  # 5m turning circle
x0 = 0
y0 = 0
th0 = 180

xf = 0
yf = 0
thf = -90

dl = 0.05
q0 = np.transpose([x0, y0, np.deg2rad(th0)])
qf = np.transpose([xf, yf, np.deg2rad(thf)])

rs = ReedsShepp(q0, qf, max_curve, dl)

rs.plot()
# Out:
# running __init__
# done __init__
# Words
# [{'word': 'lrl', 'lengths': array([ 2.1201552 , -3.61367124,  2.1201552 ]), 'L': 7.853981633974485, 'traj': [array([[ 0.00000000e+00,  0.00000000e+00,  3.14159265e+00],
#        [-4.99991667e-02, -2.49997917e-04,  3.15159265e+00],
#        [-9.99933335e-02, -9.99966667e-04,  3.16159265e+00],
#        [-1.49977510e-01, -2.24983221e-03,  3.17159265e+00],
#        [-1.99946710e-01, -3.99947073e-03,  3.18159265e+00],
#        [-2.49895921e-01, -6.24870589e-03,  3.19159265e+00],
#        [-2.99820140e-01, -8.99731166e-03,  3.20159265e+00],
#        [-3.49714366e-01, -1.22450124e-02,  3.21159265e+00],
#        [-3.99573607e-01, -1.59914830e-02,  3.22159265e+00],
#        [-4.49392876e-01, -2.02363485e-02,  3.23159265e+00],
#        [-4.99167192e-01, -2.49791846e-02,  3.24159265e+00],
#        [-5.48891580e-01, -3.02195173e-02,  3.25159265e+00],
#        [-5.98561074e-01, -3.59568230e-02,  3.26159265e+00],
# ...
