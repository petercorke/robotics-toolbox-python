# %%
# %matplotlib notebook
import ropy as rp
import numpy as np

a1 = 1
E = rp.ETS([rp.ET.TRz(), rp.ET.Ttx(a1)])
# Out:
# using colored output

# %%
E.fkine(30 * np.pi/180)
# Out:
# SE3(array([[ 0.8660254, -0.5      ,  0.       ,  0.8660254],
#            [ 0.5      ,  0.8660254,  0.       ,  0.5      ],
#            [ 0.       ,  0.       ,  1.       ,  0.       ],
#            [ 0.       ,  0.       ,  0.       ,  1.       ]]))

# %%
E.teach2()

# %%
E.plot2(block=True)
# Out:
# <img src="data:image/png;base64,..." width="300">
